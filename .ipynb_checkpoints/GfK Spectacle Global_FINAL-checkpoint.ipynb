# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import log_loss, roc_auc_score, recall_score, precision_score, average_precision_score, f1_score, classification_report, accuracy_score, plot_roc_curve, plot_precision_recall_curve, plot_confusion_matrix
import nltk
from nltk import word_tokenize
import re
from sklearn import feature_extraction, feature_selection, model_selection, naive_bayes, pipeline, manifold, preprocessing
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_selection import SelectKBest, f_classif, chi2
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB

# %%
data = pd.read_excel(r"C:\Users\gog10\GfK_spectacle_lenses_data.xlsx")

# %%
#Replace null values in the data
data.loc[data['main_text'].isnull(), 'main_text'] = 'Not Known'
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3549 entries, 0 to 3548
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   item_id         3549 non-null   int64
#  1   main_text       3549 non-null   object
#  2   country_name    3549 non-null   object
#  3   retailer_pg     3549 non-null   object
#  4   mdm_brand_text  3549 non-null   object
#  5   mdm_model_text  3549 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 166.5+ KB

# %%
#Get counts for item_id - assess if it can be split into categorical data
data['item_id'].value_counts()
# Out:
# 82981040     290
# 138176095    226
# 87099837     116
# 88210952      71
# 79429232      51
#             ...
# 81343196       5
# 122769301      5
# 124336576      5
# 119795873      5
# 64840970       5
# Name: item_id, Length: 260, dtype: int64

# %%
#Get counts for retailer_pg  - messy data so needs to be processed first
data['retailer_pg'].value_counts()
# Out:
# GLA                                 1278
# CRISTALES                            900
# LENTES                               304
# LENTE                                177
# UNASSIGNED                           168
# LENTES OFTALMICAS                    124
# LENTE|ORGANICA|PROGRESIVA             83
# LENTE|ORGANICA|MONOFOCAL              80
# LENTES//ORGANICA MONOFOCAL            64
# LENTES//ORGANICA PROGRESIVA           40
# ?253                                  31
# LENTES ORGANICA MONOFOCAL             30
# SF06                                  30
# LENTE|ORGANICA PROGRESIVA             28
# LENTE|ORGANICA MONOFOCAL              26
# VIDRES                                25
# LENTES|ORGANICA MONOFOCAL             24
# LENTES OFTÂŒMICAS                     21
# LENTES/CRISTALES                      19
# LENTES|ORGANICA PROGRESIVA            13
# MONOFOCAL                             12
# LENTES ORGANICA PROGRESIVA            11
# PROGRESIVO                            10
# 722803 - LENTES PROMOCION              6
# LENTES OFTÁLMICAS                      5
# LENTES//MONOFOCAL//ORGÁNICA            5
# LENTE|MONOFOCAL                        5
# LENTE|PROGRESIVA                       4
# LENTE|MINERAL|MONOFOCAL                4
# LENTES//PROGRESIVA//ORGÁNICA           4
# 722802 - LENTES ECI                    3
# 722801 - LENTES                        2
# LENTES//MINERAL MONOFOCAL              2
# LENTES//ORGANICA BIFOCAL               1
# LOFT/ESTD/MONO/ORGAN                   1
# LENTE|MINERAL|PROGRESIVA               1
# LENTE|ORGANICA BIFOCAL                 1
# MONT                                   1
# LENTES//POLICARBONATO PROGRESIVA       1
# LENTE|ORGANICA|BIFOCAL                 1
# GL                                     1
# SUPLEMENTO|SOL|.                       1
# ||PROGRESIVA                           1
# LOFT/ESTD/PROG/ORGAN                   1
# Name: retailer_pg, dtype: int64

# %%
#Get counts for main_text - messy data so needs to be processed first
data['main_text'].value_counts()
# Out:
# BALANSIS 1.60 (RX)                                                    24
# ID1.60LIFESTL3IURBAN(RX)                                              22
# HILUX 1.60 EYAS (RX)                                                  13
# ?ROD  L2LK?  -  ?ROD  SU?                                             12
# ZEISS ES SPH 1.6  -  LOTUTEC                                          12
#                                                                       ..
# ?ESS  GFB100?  -  ?ESS  676?                                           1
# ?EO  GFB540?  -  ?EO  676?                                             1
# ?ES-  G8E634?  -  ?ES-  675?                                           1
# ?NIKA 113?  -  ?NIKA 199?                                              1
# CRISTALES 34244 MI LIFESTYLE 3I 1.5 BC PROGRESIVO ORGÁNICO HVLL BC     1
# Name: main_text, Length: 2815, dtype: int64

# %%
#Counts by country
country_count = data['country_name'].value_counts()
country_count
# Out:
# SPAIN      2270
# GERMANY    1279
# Name: country_name, dtype: int64

# %%
#Plot counts by country
sns.set(style="darkgrid")
sns.barplot(x = country_count.index, y = country_count.values, alpha=0.9)
plt.title('Frequency Distribution of Countries')
plt.ylabel('Frequency', fontsize=12)
plt.xlabel('Country', fontsize=12)
plt.show()

# %%
#Denote country name into numerical categories
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
categorical_col = ['country_name']
for col in categorical_col:
    data[col] = l.fit_transform(data[col])
data.head()
# Out:
#      item_id                 main_text  country_name retailer_pg  \
# 0  138176095  ID1.60LIFESTL3IURBAN(RX)             1   CRISTALES
# 1  138176095  ID1.60LIFESTL3IURBAN(RX)             1   CRISTALES
# 2  138176095  ID1.60LIFESTL3IURBAN(RX)             1   CRISTALES
# 3  138176095  ID1.60LIFESTL3IURBAN(RX)             1   CRISTALES
# 4  138176095  ID1.60LIFESTL3IURBAN(RX)             1   CRISTALES
#
#   mdm_brand_text                 mdm_model_text
# 0           HOYA  HOYALUX ID LIFESTYLE 3-I HVLL
# 1           HOYA  HOYALUX ID LIFESTYLE 3-I HVLL
# 2           HOYA  HOYALUX ID LIFESTYLE 3-I HVLL
# 3           HOYA  HOYALUX ID LIFESTYLE 3-I HVLL
# 4           HOYA  HOYALUX ID LIFESTYLE 3-I HVLL

# %%
#Try splitting dataframe into countries
data_germany = data[data['country_name'] == 0]
data_spain = data[data['country_name'] == 1]
data_spain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2270 entries, 0 to 3548
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   item_id         2270 non-null   int64
#  1   main_text       2270 non-null   object
#  2   country_name    2270 non-null   int32
#  3   retailer_pg     2270 non-null   object
#  4   mdm_brand_text  2270 non-null   object
#  5   mdm_model_text  2270 non-null   object
# dtypes: int32(1), int64(1), object(4)
# memory usage: 115.3+ KB

# %%
#Check retailer_pg counts for Spain only
data_spain['retailer_pg'].value_counts()
# Out:
# CRISTALES                           900
# LENTES                              304
# LENTE                               177
# UNASSIGNED                          168
# LENTES OFTALMICAS                   124
# LENTE|ORGANICA|PROGRESIVA            83
# LENTE|ORGANICA|MONOFOCAL             80
# LENTES//ORGANICA MONOFOCAL           64
# LENTES//ORGANICA PROGRESIVA          40
# ?253                                 31
# LENTES ORGANICA MONOFOCAL            30
# SF06                                 30
# LENTE|ORGANICA PROGRESIVA            28
# LENTE|ORGANICA MONOFOCAL             26
# VIDRES                               25
# LENTES|ORGANICA MONOFOCAL            24
# LENTES OFTÂŒMICAS                    21
# LENTES/CRISTALES                     19
# LENTES|ORGANICA PROGRESIVA           13
# MONOFOCAL                            12
# LENTES ORGANICA PROGRESIVA           11
# PROGRESIVO                           10
# 722803 - LENTES PROMOCION             6
# LENTE|MONOFOCAL                       5
# LENTES//MONOFOCAL//ORGÁNICA           5
# LENTES OFTÁLMICAS                     5
# LENTE|MINERAL|MONOFOCAL               4
# LENTES//PROGRESIVA//ORGÁNICA          4
# LENTE|PROGRESIVA                      4
# 722802 - LENTES ECI                   3
# 722801 - LENTES                       2
# LENTES//MINERAL MONOFOCAL             2
# LENTE|ORGANICA BIFOCAL                1
# MONT                                  1
# LOFT/ESTD/PROG/ORGAN                  1
# LENTE|MINERAL|PROGRESIVA              1
# LENTES//ORGANICA BIFOCAL              1
# LOFT/ESTD/MONO/ORGAN                  1
# LENTE|ORGANICA|BIFOCAL                1
# SUPLEMENTO|SOL|.                      1
# ||PROGRESIVA                          1
# LENTES//POLICARBONATO PROGRESIVA      1
# Name: retailer_pg, dtype: int64

# %%
#Check retailer_pg counts for Germany only
data_germany['retailer_pg'].value_counts()
# Out:
# GLA    1278
# GL        1
# Name: retailer_pg, dtype: int64

# %%
#Use Global model
#Delete columns not needed for model
data.drop(['country_name', 'mdm_brand_text', 'mdm_model_text'], axis = 'columns', inplace=True)

# %%
data.head()
# Out:
#      item_id                 main_text retailer_pg
# 0  138176095  ID1.60LIFESTL3IURBAN(RX)   CRISTALES
# 1  138176095  ID1.60LIFESTL3IURBAN(RX)   CRISTALES
# 2  138176095  ID1.60LIFESTL3IURBAN(RX)   CRISTALES
# 3  138176095  ID1.60LIFESTL3IURBAN(RX)   CRISTALES
# 4  138176095  ID1.60LIFESTL3IURBAN(RX)   CRISTALES

# %%
#find out more about each item_id, how many unique
data.groupby('item_id').describe()
# Out:
#           main_text                                                            \
#               count unique                                                top
# item_id
# 2296911          25     25                      ?HOP  PEHLS?  -  ?HOP  PEHVL?
# 18378494         13     10                                MASTERLUX 1.9 AS AD
# 18378561          9      9  CRISTALES SUPERKID LITE/MONOFOCAL/ORGANICO/1,5...
# 18378572         21     21  CRISTALES TELEGRAND 1.523 ICR.MA.(MIN.Ø7/BIFOC...
# 18378781         24     23           LENTE 414 FLINT 35 LAB MINERAL MONOFOCAL
# ...             ...    ...                                                ...
# 143678129         5      4                       ?ESE  561540?  -  ?ESE  760?
# 143679284         6      4                            ?ESE  AZ6540?  -  ?ESE?
# 144314284         8      8  CRISTALES 254 045 -02.00 -07.00  ZEISS 1,67 VE...
# 144542015        17     17  MODELO: LENTE DE SOL MONOFOCAL 1.6AS UNIFORME/...
# 144542026        11     11  MODELO: LENTE DE SOL ASFERICA MONOFOCAL 1,67 U...
#
#                retailer_pg
#           freq       count unique        top freq
# item_id
# 2296911      1          25      2        GLA   24
# 18378494     3          13      7  CRISTALES    3
# 18378561     1           9      4  CRISTALES    4
# 18378572     1          21      5  CRISTALES   13
# 18378781     2          24      6     VIDRES   10
# ...        ...         ...    ...        ...  ...
# 143678129    2           5      1        GLA    5
# 143679284    3           6      1        GLA    6
# 144314284    1           8      1  CRISTALES    8
# 144542015    1          17      1  CRISTALES   17
# 144542026    1          11      1  CRISTALES   11
#
# [260 rows x 8 columns]

# %%
#find length of text in main_text
data['length'] = data['main_text'].apply(len)
data.head(20)
# Out:
#       item_id                                          main_text  \
# 0   138176095                           ID1.60LIFESTL3IURBAN(RX)
# 1   138176095                           ID1.60LIFESTL3IURBAN(RX)
# 2   138176095                           ID1.60LIFESTL3IURBAN(RX)
# 3   138176095                           ID1.60LIFESTL3IURBAN(RX)
# 4   138176095                           ID1.60LIFESTL3IURBAN(RX)
# 5   101261697                       ESS ILIKIA XTRA FIT ORMIX 16
# 6   101261697                       ESS ILIKIA XTRA FIT ORMIX 16
# 7   140544215                                 BALANSIS 1.60 (RX)
# 8   140544215                                 BALANSIS 1.60 (RX)
# 9   138176095  CRISTALES ID1.60LIFESTL3URBAN(RX)/PROGRESIVOS/...
# 10  138176095                           ID1.60LIFESTL3IURBAN(RX)
# 11  140544215                                 BALANSIS 1.60 (RX)
# 12  140544215                                 BALANSIS 1.60 (RX)
# 13  140544215                                 BALANSIS 1.60 (RX)
# 14  140544215                                 BALANSIS 1.60 (RX)
# 15  140544215                                 BALANSIS 1.60 (RX)
# 16  140544215                                 BALANSIS 1.60 (RX)
# 17  140544215                                 BALANSIS 1.60 (RX)
# 18  140544215                                 BALANSIS 1.60 (RX)
# 19  138176095                           ID1.60LIFESTL3IURBAN(RX)
#
#           retailer_pg  length
# 0           CRISTALES      24
# 1           CRISTALES      24
# 2           CRISTALES      24
# 3           CRISTALES      24
# 4           CRISTALES      24
# 5           CRISTALES      28
# 6           CRISTALES      28
# 7           CRISTALES      18
# 8           CRISTALES      18
# 9   LENTES OFTALMICAS      79
# 10          CRISTALES      24
# 11          CRISTALES      18
# 12          CRISTALES      18
# 13          CRISTALES      18
# 14          CRISTALES      18
# 15          CRISTALES      18
# 16          CRISTALES      18
# 17          CRISTALES      18
# 18          CRISTALES      18
# 19          CRISTALES      24

# %%
#find out min and max length of text
data['length'].describe()
# Out:
# count    3549.000000
# mean       44.286841
# std        28.083193
# min         4.000000
# 25%        25.000000
# 50%        36.000000
# 75%        53.000000
# max       180.000000
# Name: length, dtype: float64

# %%
#look at longest text - needs pre-processing
data[data['length'] == 180]['main_text'].iloc[0]
# Out:
# 'MODELO: LENTE DE SOL ASFERICA MONOFOCAL 1,67 UNIFORME//GÉNERO: MONO//MATERIAL: ORG//ANTIRREFLEJANTE: NO//ANTIRRAYADO: NO//COLOR: PTDCGVMEDIO3 DEG MEDIO GRIS VERDE//FOTOCROMÁTICO: -'

# %%
#visualize distribution of main_text length
data['length'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# rename columns for model
data = data.rename(columns={"item_id":"y", "main_text":"text", "retailer_pg":"pg"})
data
# Out:
#               y                                               text         pg  \
# 0     138176095                           ID1.60LIFESTL3IURBAN(RX)  CRISTALES
# 1     138176095                           ID1.60LIFESTL3IURBAN(RX)  CRISTALES
# 2     138176095                           ID1.60LIFESTL3IURBAN(RX)  CRISTALES
# 3     138176095                           ID1.60LIFESTL3IURBAN(RX)  CRISTALES
# 4     138176095                           ID1.60LIFESTL3IURBAN(RX)  CRISTALES
# ...         ...                                                ...        ...
# 3544   25278162  CRISTALES 34212 MI MF XPERIENCE 1.5 BASIC HV P...  CRISTALES
# 3545  115519055  CRISTALES 34186 MI HILUX 1.6 SHV FAB MONOFOCAL...  CRISTALES
# 3546  112904161  CRISTALES 34317 NULUX ACTIVE TF 1.5 HV ORGÁNIC...  CRISTALES
# 3547  138176095  CRISTALES 34244 MI LIFESTYLE 3I 1.5 HVLL BC PR...  CRISTALES
# 3548  138176095  CRISTALES 34244 MI LIFESTYLE 3I 1.5 BC PROGRES...  CRISTALES
#
#       length
# 0         24
# 1         24
# 2         24
# 3         24
# 4         24
# ...      ...
# 3544      67
# 3545      55
# 3546      57
# 3547      71
# 3548      66
#
# [3549 rows x 4 columns]

# %%
#list of stop words from nltk
lst_stopwords = nltk.corpus.stopwords.fileids()
lst_stopwords
# Out:
# ['arabic',
#  'azerbaijani',
#  'bengali',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'greek',
#  'hungarian',
#  'indonesian',
#  'italian',
#  'kazakh',
#  'nepali',
#  'norwegian',
#  'portuguese',
#  'romanian',
#  'russian',
#  'slovene',
#  'spanish',
#  'swedish',
#  'tajik',
#  'turkish']

# %%
#create a function to remove these stop words, remove certain characters, stem the text and lemmatize the text in main text
'''
Preprocess a string.
:parameter
    :param text: string - name of column containing text
    :param lst_stopwords: list - list of stopwords to remove
    :param flg_stemm: bool - whether stemming is to be applied
    :param flg_lemm: bool - whether lemmitisation is to be applied
:return
    cleaned text
'''
def preprocess_text(text, flg_stemm=False, flg_lemm=True, lst_stopwords=None):
    ## clean (remove punctuations and characters and then strip)
    text = re.sub(r'[^\w\s]', '', str(text).strip())
            
    ## Tokenize (convert from string to list)
    lst_text = text.split()
    
    ## remove Stopwords
    if lst_stopwords is not None:
        lst_text = [word for word in lst_text if word not in 
                    lst_stopwords]
                
    ## Stemming (remove -ing, -ly, ...)
    if flg_stemm == True:
        ps = nltk.stem.porter.PorterStemmer()
        lst_text = [ps.stem(word) for word in lst_text]
                
    ## Lemmatisation (convert the word into root word)
    if flg_lemm == True:
        lem = nltk.stem.wordnet.WordNetLemmatizer()
        lst_text = [lem.lemmatize(word) for word in lst_text]
            
    ## back to string from list
    text = " ".join(lst_text)
    return text

# %%
#create a function to remove these stop words, remove certain characters, stem the text and lemmatize the text for pg
'''
Preprocess a string.
:parameter
    :param text: string - name of column containing text
    :param lst_stopwords: list - list of stopwords to remove
    :param flg_stemm: bool - whether stemming is to be applied
    :param flg_lemm: bool - whether lemmitisation is to be applied
:return
    cleaned text
'''
def preprocess_pg(pg, flg_stemm=False, flg_lemm=True, lst_stopwords=None):
    ## clean (remove punctuations and characters and then strip)
    pg = re.sub(r'[^\w\s]', '', str(pg).strip())
            
    ## Tokenize (convert from string to list)
    lst_pg = pg.split()
    ## remove Stopwords
    if lst_stopwords is not None:
        lst_pg = [word for word in lst_pg if word not in 
                    lst_stopwords]
                
    ## Stemming (remove -ing, -ly, ...)
    if flg_stemm == True:
        ps = nltk.stem.porter.PorterStemmer()
        lst_pg = [ps.stem(word) for word in lst_pg]
                
    ## Lemmatisation (convert the word into root word)
    if flg_lemm == True:
        lem = nltk.stem.wordnet.WordNetLemmatizer()
        lst_pg = [lem.lemmatize(word) for word in lst_pg]
            
    ## back to string from list
    pg = " ".join(lst_pg)
    return pg

# %%
#Apply the function for text
data["text_clean"] = data["text"].apply(lambda x: 
          preprocess_text(x, flg_stemm=False, flg_lemm=True, 
          lst_stopwords=lst_stopwords))

# %%
#Apply the function for pg
data["pg_clean"] = data["pg"].apply(lambda x: 
          preprocess_pg(x, flg_stemm=False, flg_lemm=True, 
          lst_stopwords=lst_stopwords))
data.head()
# Out:
#            y                      text         pg  length  \
# 0  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES      24
# 1  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES      24
# 2  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES      24
# 3  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES      24
# 4  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES      24
#
#               text_clean   pg_clean
# 0  ID160LIFESTL3IURBANRX  CRISTALES
# 1  ID160LIFESTL3IURBANRX  CRISTALES
# 2  ID160LIFESTL3IURBANRX  CRISTALES
# 3  ID160LIFESTL3IURBANRX  CRISTALES
# 4  ID160LIFESTL3IURBANRX  CRISTALES

# %%
#find out length of text_clean
data['length_clean'] = data['text_clean'].apply(len)
data.head(20)
# Out:
#             y                                               text  \
# 0   138176095                           ID1.60LIFESTL3IURBAN(RX)
# 1   138176095                           ID1.60LIFESTL3IURBAN(RX)
# 2   138176095                           ID1.60LIFESTL3IURBAN(RX)
# 3   138176095                           ID1.60LIFESTL3IURBAN(RX)
# 4   138176095                           ID1.60LIFESTL3IURBAN(RX)
# 5   101261697                       ESS ILIKIA XTRA FIT ORMIX 16
# 6   101261697                       ESS ILIKIA XTRA FIT ORMIX 16
# 7   140544215                                 BALANSIS 1.60 (RX)
# 8   140544215                                 BALANSIS 1.60 (RX)
# 9   138176095  CRISTALES ID1.60LIFESTL3URBAN(RX)/PROGRESIVOS/...
# 10  138176095                           ID1.60LIFESTL3IURBAN(RX)
# 11  140544215                                 BALANSIS 1.60 (RX)
# 12  140544215                                 BALANSIS 1.60 (RX)
# 13  140544215                                 BALANSIS 1.60 (RX)
# 14  140544215                                 BALANSIS 1.60 (RX)
# 15  140544215                                 BALANSIS 1.60 (RX)
# 16  140544215                                 BALANSIS 1.60 (RX)
# 17  140544215                                 BALANSIS 1.60 (RX)
# 18  140544215                                 BALANSIS 1.60 (RX)
# 19  138176095                           ID1.60LIFESTL3IURBAN(RX)
#
#                    pg  length  \
# 0           CRISTALES      24
# 1           CRISTALES      24
# 2           CRISTALES      24
# 3           CRISTALES      24
# 4           CRISTALES      24
# 5           CRISTALES      28
# 6           CRISTALES      28
# 7           CRISTALES      18
# 8           CRISTALES      18
# 9   LENTES OFTALMICAS      79
# 10          CRISTALES      24
# 11          CRISTALES      18
# 12          CRISTALES      18
# 13          CRISTALES      18
# 14          CRISTALES      18
# 15          CRISTALES      18
# 16          CRISTALES      18
# 17          CRISTALES      18
# 18          CRISTALES      18
# 19          CRISTALES      24
#
#                                            text_clean           pg_clean  \
# 0                               ID160LIFESTL3IURBANRX          CRISTALES
# 1                               ID160LIFESTL3IURBANRX          CRISTALES
# 2                               ID160LIFESTL3IURBANRX          CRISTALES
# 3                               ID160LIFESTL3IURBANRX          CRISTALES
# 4                               ID160LIFESTL3IURBANRX          CRISTALES
# 5                        ESS ILIKIA XTRA FIT ORMIX 16          CRISTALES
# 6                        ESS ILIKIA XTRA FIT ORMIX 16          CRISTALES
# 7                                     BALANSIS 160 RX          CRISTALES
# 8                                     BALANSIS 160 RX          CRISTALES
# 9   CRISTALES ID160LIFESTL3URBANRXPROGRESIVOSORGAN...  LENTES OFTALMICAS
# 10                              ID160LIFESTL3IURBANRX          CRISTALES
# 11                                    BALANSIS 160 RX          CRISTALES
# 12                                    BALANSIS 160 RX          CRISTALES
# 13                                    BALANSIS 160 RX          CRISTALES
# 14                                    BALANSIS 160 RX          CRISTALES
# 15                                    BALANSIS 160 RX          CRISTALES
# 16                                    BALANSIS 160 RX          CRISTALES
# 17                                    BALANSIS 160 RX          CRISTALES
# 18                                    BALANSIS 160 RX          CRISTALES
# 19                              ID160LIFESTL3IURBANRX          CRISTALES
#
#     length_clean
# 0             21
# 1             21
# 2             21
# 3             21
# 4             21
# 5             28
# 6             28
# 7             15
# 8             15
# 9             69
# 10            21
# 11            15
# 12            15
# 13            15
# 14            15
# 15            15
# 16            15
# 17            15
# 18            15
# 19            21

# %%
#find out min and max length of text_clean - shorter now
data['length_clean'].describe()
# Out:
# count    3549.000000
# mean       37.801916
# std        26.056621
# min         4.000000
# 25%        17.000000
# 50%        33.000000
# 75%        48.000000
# max       160.000000
# Name: length_clean, dtype: float64

# %%
#Re-look at longest text - can see punctuation is removed
data[data['length_clean'] == 160]['text_clean'].iloc[0]
# Out:
# 'LENTES OFTÁLMICAS CARL ZEISS VISION ESPAÑA SL CARL ZEISS VISION ESPAÑA SL OFFICELENSSUPERBNEAR CRISTALES PROGRESIVOS ORGANICO 1500 DURAVISION PLATINUM SIN COLOR'

# %%
#Combine text and pg
data["text_combined"] = data.text_clean + data.pg_clean
y = data['y']
data.head()
# Out:
#            y                      text         pg  length  \
# 0  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES      24
# 1  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES      24
# 2  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES      24
# 3  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES      24
# 4  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES      24
#
#               text_clean   pg_clean  length_clean  \
# 0  ID160LIFESTL3IURBANRX  CRISTALES            21
# 1  ID160LIFESTL3IURBANRX  CRISTALES            21
# 2  ID160LIFESTL3IURBANRX  CRISTALES            21
# 3  ID160LIFESTL3IURBANRX  CRISTALES            21
# 4  ID160LIFESTL3IURBANRX  CRISTALES            21
#
#                     text_combined
# 0  ID160LIFESTL3IURBANRXCRISTALES
# 1  ID160LIFESTL3IURBANRXCRISTALES
# 2  ID160LIFESTL3IURBANRXCRISTALES
# 3  ID160LIFESTL3IURBANRXCRISTALES
# 4  ID160LIFESTL3IURBANRXCRISTALES

# %%
#convert to token count matrix
bow_transformer = CountVectorizer(max_features=None, ngram_range=(1,1)).fit(data['text_combined'])

# %%
#count number of vocab words
print(len(bow_transformer.vocabulary_))
# Out:
# 2638

# %%
bow_transformer.get_feature_names()
# Out:
# ['00',
#  '000',
#  '0000',
#  '000202',
#  '0002cristales',
#  '001101',
#  '001102',
#  '0016cristales',
#  '0025',
#  '004',
#  '005',
#  '0050',
#  '007001',
#  '007101',
#  '007201',
#  '0075',
#  '008',
#  '01',
#  '010',
#  '0100',
#  '010gla',
#  '0125',
#  '015',
#  '0150',
#  '015000',
#  '015402',
#  '0160cristales',
#  '016100',
#  '017307',
#  '0174cristales',
#  '0175',
#  '0200',
#  '021000',
#  '0225',
#  '023gla',
#  '025',
#  '0250',
#  '0275',
#  '0276',
#  '030',
#  '0300',
#  '032',
#  '0325',
#  '035',
#  '0350',
#  '0375',
#  '04',
#  '040',
#  '0400',
#  '0425',
#  '044',
#  '044gla',
#  '045',
#  '0450',
#  '045gla',
#  '046',
#  '0475',
#  '048901',
#  '04monofocal',
#  '05',
#  '050',
#  '0525',
#  '053',
#  '053cristales',
#  '055',
#  '0550',
#  '0575',
#  '058',
#  '06',
#  '060',
#  '0600',
#  '0625',
#  '070',
#  '0700',
#  '075',
#  '0750',
#  '079000',
#  '080',
#  '085',
#  '085d',
#  '088',
#  '090',
#  '0909',
#  '090gla',
#  '092',
#  '095',
#  '0a',
#  '0a14vidres',
#  '0a16vidres',
#  '0unassigned',
#  '10',
#  '100',
#  '10042',
#  '10045',
#  '10053',
#  '10080',
#  '100º',
#  '101202',
#  '1018',
#  '10201',
#  '1021',
#  '103º',
#  '104',
#  '1043',
#  '104gla',
#  '105',
#  '105gla',
#  '10679',
#  '10680',
#  '10680gla',
#  '10683',
#  '106cristales',
#  '108',
#  '10897',
#  '10938',
#  '10cristales',
#  '10º',
#  '11',
#  '110',
#  '110º',
#  '1122',
#  '1127',
#  '113',
#  '11342',
#  '11413',
#  '11496',
#  '115',
#  '11518',
#  '11560',
#  '11584',
#  '115º',
#  '1162',
#  '1167',
#  '117',
#  '11cristales',
#  '11lenteorganicaprogresiva',
#  '11mm',
#  '11monofocalorganico0sin',
#  '11sin',
#  '12',
#  '120',
#  '120100',
#  '120º',
#  '121',
#  '121100',
#  '1230',
#  '12379',
#  '1244',
#  '125',
#  '125º',
#  '126',
#  '12636',
#  '12689',
#  '1270',
#  '12703',
#  '1299',
#  '13',
#  '130',
#  '130º',
#  '13103',
#  '13124',
#  '1317',
#  '13238',
#  '13343',
#  '13370',
#  '13413',
#  '13435',
#  '13435gla',
#  '135',
#  '13501',
#  '13501gla',
#  '136100',
#  '13629',
#  '13641',
#  '13737',
#  '1384',
#  '13881',
#  '14',
#  '140',
#  '14000',
#  '14175',
#  '14220',
#  '143',
#  '144',
#  '145',
#  '145205',
#  '146',
#  '14859',
#  '14cristales',
#  '14lenteorganicaprogresiva',
#  '14mm',
#  '15',
#  '150',
#  '1500',
#  '1500cristales',
#  '1500loftestdmonoorgan',
#  '1507',
#  '150gla',
#  '152',
#  '1523',
#  '153',
#  '154',
#  '154cristales',
#  '155',
#  '155º',
#  '15cristales',
#  '15género',
#  '15lentemonofocal',
#  '15lenteorganicamonofocal',
#  '15lenteorganicaprogresiva',
#  '15lentescristales',
#  '15º',
#  '16',
#  '160',
#  '1600',
#  '1600cristales',
#  '160monofocalorganico0hmcsin',
#  '160º',
#  '161',
#  '16253',
#  '165',
#  '16569',
#  '16637',
#  '167',
#  '1670',
#  '1670loftestdprogorgan',
#  '167asferico',
#  '167cristales',
#  '167lente',
#  '167lentemonofocal',
#  '167lenteorganicamonofocal',
#  '167lenteorganicaprogresiva',
#  '167lenteprogresiva',
#  '167monofocalorganico1670hmcsin',
#  '16as',
#  '16cristales',
#  '16gla',
#  '16género',
#  '16lentemineralmonofocal',
#  '16lenteorganica',
#  '16lenteorganicaprogresiva',
#  '16lentes',
#  '16monofocalorganico0hmcsin',
#  '16monofocalorganico1599crizal',
#  '16monofocalorganico1600con',
#  '16nexoprogresivoorganicounassigned',
#  '16progresivosmineral1600superdiafal',
#  '16progresivosmineral2000superdiafal',
#  '16progresivosmineral2000superdiafalsin',
#  '16progresivosorganico0hvllsin',
#  '16progresivosorganico0hvlsin',
#  '16progresivosorganico1599crizal',
#  '16progresivosorganico1600crizal',
#  '16progresivosorganico1600hvllsin',
#  '16progresivosorganico1600semiespejo',
#  '16progresivosorganico2000crizal',
#  '16progresivosorganico2crizal',
#  '16rx',
#  '16rxcristales',
#  '16rxlenteorganicamonofocal',
#  '16rxlentes',
#  '16rxmonofocalorganico1600con',
#  '16rxmonofocalorganico1600hardcon',
#  '16st',
#  '16unassigned',
#  '17',
#  '170',
#  '170º',
#  '1732',
#  '174',
#  '174cristales',
#  '174lentescristales',
#  '174monofocalorganico0sccsin',
#  '174monofocalorganico0scuvsin',
#  '174monofocalorganico0shmcsin',
#  '174monofocalorganico1740scc',
#  '175',
#  '17656',
#  '17841',
#  '17cristales',
#  '18',
#  '180',
#  '1800',
#  '180º',
#  '1859',
#  '1867',
#  '187',
#  '1882',
#  '188cristales',
#  '1899',
#  '18cristales',
#  '18lentesorganica',
#  '19',
#  '190',
#  '1944',
#  '1948',
#  '1953',
#  '196',
#  '1982',
#  '19851',
#  '199gla',
#  '19género',
#  '1cristales',
#  '1cz',
#  '1gl',
#  '1gla',
#  '1género',
#  '1r',
#  '1rgla',
#  '1rh',
#  '1rhgla',
#  '20',
#  '200',
#  '201',
#  '20156',
#  '2018166monofocal',
#  '202',
#  '2031',
#  '204100',
#  '205',
#  '208',
#  '2085',
#  '20º',
#  '2132',
#  '217100',
#  '217631',
#  '2180',
#  '2186',
#  '22235',
#  '225',
#  '2250',
#  '226',
#  '2263',
#  '2266',
#  '2281',
#  '2282',
#  '23',
#  '230lentes',
#  '2419',
#  '2428',
#  '2431',
#  '2438',
#  '2439',
#  '2479',
#  '2480',
#  '2485',
#  '2486',
#  '24h',
#  '25',
#  '250',
#  '2503',
#  '250350',
#  '2504',
#  '251',
#  '25240',
#  '25292',
#  '254',
#  '2540',
#  '2541',
#  '2581',
#  '25816',
#  '2582',
#  '2584',
#  '2598',
#  '2599',
#  '259gla',
#  '25lenteorganica',
#  '25º',
#  '2602',
#  '2603',
#  '2641',
#  '2642',
#  '2649',
#  '2659',
#  '26600',
#  '26629',
#  '26639',
#  '2664',
#  '2665',
#  '2670',
#  '2671',
#  '269100',
#  '269307',
#  '2708',
#  '2709',
#  '270gla',
#  '2713',
#  '2714',
#  '2719',
#  '2725',
#  '2726',
#  '2731',
#  '275',
#  '2752',
#  '2761',
#  '2762',
#  '2774',
#  '2779',
#  '28',
#  '2807',
#  '2808',
#  '281gla',
#  '2831',
#  '2832',
#  '2862',
#  '2863',
#  '2866',
#  '2877',
#  '2878',
#  '288100',
#  '28879',
#  '2909',
#  '29534',
#  '2976',
#  '2982',
#  '2983',
#  '29938',
#  '2a',
#  '2a16vidres',
#  '2cz',
#  '2czgla',
#  '2es',
#  '2esgla',
#  '2ro',
#  '2rogla',
#  '2vidres',
#  '2vs',
#  '2x1',
#  '2x1cristales',
#  '30',
#  '300',
#  '3022',
#  '3023',
#  '3063',
#  '3072',
#  '30822',
#  '3100',
#  '314100',
#  '318100',
#  '325',
#  '3253',
#  '3256',
#  '32586',
#  '32642',
#  '33124',
#  '33132',
#  '33285',
#  '33320',
#  '3341',
#  '33429',
#  '33456',
#  '33483',
#  '33574',
#  '33632',
#  '33642',
#  '33649',
#  '60175675lentes',
#  '60250150lente',
#  '60250200lente',
#  '60275500lente',
#  '60300400lente',
#  '60325525lentes',
#  '60325550lentes',
#  '60350250lentes',
#  '60400100lente',
#  '60400325lentes',
#  '6065',
#  '6065lentes',
#  '6065lentesorganica',
#  '60cristales',
#  '60eoptima',
#  '60lentes',
#  '60lentesorganica',
#  '60lentespolicarbonato',
#  '60x50',
#  '60x50cristales',
#  '60º',
#  '62',
#  '625',
#  '6253',
#  '6267',
#  '62800',
#  '6399',
#  '6414',
#  '6437',
#  '64400',
#  '6445',
#  '6467',
#  '6492',
#  '65',
#  '65000050lente',
#  '65000050lentes',
#  '65000100',
#  '65000100lentes',
#  '65000125',
#  '65000125lentes',
#  '65000150lentes',
#  '65000175lentes',
#  '65000200lente',
#  '65000200lentes',
#  '65000225lentes',
#  '65000250lentes',
#  '65000375lente',
#  '65000425lentes',
#  '65000475lentes',
#  '65000600',
#  '65000600lentes',
#  '65025025lentes',
#  '65025125lentes',
#  '65025150lente',
#  '65025200lentes',
#  '65025250lentes',
#  '65025275lentes',
#  '65025300lentes',
#  '65025325lentes',
#  '65025650',
#  '65050025lentes',
#  '65050050',
#  '65050150lentes',
#  '65050300lentes',
#  '65050575',
#  '65050600lentes',
#  '65075025lentes',
#  '65075150lentes',
#  '65075275lente',
#  '65075275lentes',
#  '65100150lente',
#  '65100150lentes',
#  '65100200lentes',
#  '65100400',
#  '65100450',
#  '65100750',
#  '65125125lentes',
#  '65125150lentes',
#  '65150450',
#  '65200600',
#  '65253',
#  '6551',
#  '65600',
#  '6570',
#  '6570cristales',
#  '6570lentesorganica',
#  '6571cristales',
#  '6571lentes',
#  '6575',
#  '6575cristales',
#  '6575lentes',
#  '6589',
#  '6594',
#  '65cristales',
#  '65e',
#  '65e65',
#  '65e6570',
#  '65lente',
#  '65lentes',
#  '65lentesmineral',
#  '65lentesorganica',
#  '65rx',
#  '65rxmonofocalorganico1530sin',
#  '65x55',
#  '65x55cristales',
#  '65º',
#  '661402',
#  '6649',
#  '67400',
#  '675gla',
#  '676gla',
#  '67ar',
#  '67argla',
#  '67nrgla',
#  '67srgla',
#  '6833',
#  '6836',
#  '6855',
#  '69',
#  '6927',
#  '6950',
#  '6956',
#  '6958',
#  '6cristales',
#  '6eu',
#  '6eugla',
#  '6lenteorganicamonofocal',
#  '6vidres',
#  '70',
#  '70000200lentes',
#  '70000225lentes',
#  '70000750lentes',
#  '70000850lentes',
#  '70025100lentes',
#  '70025225lente',
#  '70050600lentes',
#  '70075025lentes',
#  '70075250lentes',
#  '7008',
#  '700lente',
#  '70100075lente',
#  '70100100lente',
#  '70100725lentes',
#  '70125075lentes',
#  '70125175lentes',
#  '70125275lentes',
#  '70125850lentes',
#  '70150050',
#  '70150100',
#  '701lente',
#  '70200075lente',
#  '70250250lente',
#  '70250300lentes',
#  '70250lentes',
#  '70253',
#  '70275675lentes',
#  '70300lentes',
#  '70350050lente',
#  '70350450',
#  '70400600',
#  '70425000lente',
#  '7075',
#  '7075cristales',
#  '7075lentes',
#  '7075lentesorganica',
#  '7076',
#  '7079',
#  '7079cristales',
#  '7080cristales',
#  '70cristales',
#  '70lentemonofocal',
#  '70lentes',
#  '70lentesorganica',
#  '70x60',
#  '70x60cristales',
#  '70º',
#  '71',
#  '712',
#  '719100',
#  '725',
#  '725100',
#  '725l',
#  '725n',
#  '725s',
#  '725x',
#  '736',
#  '736n',
#  '736s',
#  '736x',
#  '737',
#  '74',
#  '7489',
#  '74nr',
#  '74sr',
#  '74zs',
#  '75',
#  '75000000lentes',
#  '75000050',
#  '75000050lentes',
#  '75000075lentes',
#  '75000100lentes',
#  '75000125lentes',
#  '75000150lentes',
#  '75000175lentes',
#  '75000200lente',
#  '75000225lente',
#  '75000225lentes',
#  '75000275lentes',
#  '75000350lentes',
#  '75000400lente',
#  '7500lente',
#  '75025025lentes',
#  '75025050lentes',
#  '75025075lentes',
#  '75025100lentes',
#  '75025150lentes',
#  '75025175lentes',
#  '75025225lentes',
#  '75025250lente',
#  '75025300lentes',
#  '75025575lentes',
#  '75050050lentes',
#  '75050075lentes',
#  '75050100lentes',
#  '75050125lentes',
#  '75050175lentes',
#  '75050200lentes',
#  '75050225lentes',
#  '75050300lentes',
#  '75050350lente',
#  '75050375lente',
#  '75050375lentes',
#  '75050400lentes',
#  '75050425lentes',
#  '75050500lentes',
#  '75050675lentes',
#  '75050750lentes',
#  '75075075lentes',
#  '75075100lente',
#  '75075100lentes',
#  '75075150lente',
#  '75075200lente',
#  '75075275lente',
#  '75075275lentes',
#  '75075300lentes',
#  '75075400lentes',
#  '75100100lente',
#  '75100100lentes',
#  '75100150lentes',
#  '75100225lentes',
#  '75100350lentes',
#  '75100450lentes',
#  '75100900lentes',
#  '75125300lentes',
#  '75125325lentes',
#  '75125425lentes',
#  '75150100lentes',
#  '75150125lentes',
#  '751fotocromáticocristales',
#  '75200275lentes',
#  '75200300lentes',
#  '75200350lentes',
#  '7523',
#  '7525',
#  '75250250lente',
#  '752540',
#  '75275575lentes',
#  '75350250lente',
#  '753fotocromáticocristales',
#  '75425300lente',
#  '75425425lentes',
#  '754fotocromáticocristales',
#  '75700',
#  '7580',
#  '7580lentes',
#  '75cristales',
#  '75lentes',
#  '75lentesorganica',
#  '75x65',
#  '75º',
#  '760',
#  '760gla',
#  '7624',
#  '76350',
#  '76450',
#  '76lentes',
#  '77075075lente',
#  '7709',
#  '77100100lente',
#  '772',
#  '77400',
#  '775100',
#  '775540',
#  '7756',
#  '785100',
#  '795540',
#  '797100',
#  '798540',
#  '7sy',
#  '7sygla',
#  '80',
#  '804307',
#  '8095',
#  '80cristales',
#  '80lentes',
#  '80º',
#  '81',
#  '815540',
#  '815634',
#  '815gla',
#  '8196',
#  '85',
#  '85cristales',
#  '85º',
#  '8734',
#  '8763',
#  '879540',
#  '880631',
#  '885',
#  '885x',
#  '894',
#  '8983',
#  '8cristales',
#  '8da',
#  '8dagla',
#  '90',
#  '901145',
#  '901513',
#  '901524',
#  '90210',
#  '9040',
#  '905',
#  '905100',
#  '90º',
#  '921',
#  '9260',
#  '934',
#  ...]

# %%
#transform to sparse matrix
text_bow = bow_transformer.transform(data['text_combined'])

# %%
#get shape of sparse matrix
print('Shape of the sparse matrix ', text_bow.shape)
# Out:
# Shape of the sparse matrix  (3549, 2638)

# %%
#Creates weight value for each word
tfidf_transformer = TfidfTransformer().fit(text_bow)

# %%
#text represented as numerical vectors
text_tfidf = tfidf_transformer.transform(text_bow)

# %%
#Use Categorical Bayes model to test
model = MultinomialNB().fit(text_tfidf, data['y'])

# %%
prediction = model.predict(text_tfidf)

# %%
prediction
# Out:
# array([138176095, 138176095, 138176095, ..., 138176095, 138176095,
#        138176095], dtype=int64)

# %%
#split data into train and test
text_train, text_test, y_train, y_test = train_test_split(data['text_combined'], data['y'], test_size=0.3)

# %%
text_train
# Out:
# 2630       ORMIX 16 CRIZAL PREVENCIA ESTOC 75050500LENTES
# 1637              NIKAT 17 SUPERBREITBANDENTSPIEGELUNGGLA
# 1833    LENTE AGP UNIQUE HD DRO TRANS G 15 CNC HFT ORG...
# 1710    EYEZEN ACTIVE PLUS 085 F360 ORMA 15 D 75 CRIZA...
# 2599    LENTE 434540 VARILUX E DESIGN STYLIS 167 EPS O...
#                               ...
# 1799    LENTES OFTÂŒMICAS HOYA LENS IBERIA SA HOYA LEN...
# 154     HILUX 150 POL GRIS HUMO RX HARDLENTEORGANICA M...
# 3216                            C28 EYAS160 77100100LENTE
# 2740              ORMIX 16 TRANS EPS 55075125 MARROLENTES
# 944                                       RHE 1122 RHEGLA
# Name: text_combined, Length: 2484, dtype: object

# %%
#Create pipeline
pipeline = Pipeline([
    ('bow', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('classifier', MultinomialNB())
    ])

# %%
#fit model
pipeline.fit(text_train, y_train)
# Out:
# Pipeline(steps=[('bow', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('classifier', MultinomialNB())])

# %%
predictions = pipeline.predict(text_test)

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#      2296911       0.00      0.00      0.00         4
#     18378494       0.00      0.00      0.00         3
#     18378561       0.00      0.00      0.00         5
#     18378572       0.00      0.00      0.00         7
#     18378781       1.00      0.86      0.92         7
#     19026396       0.00      0.00      0.00         3
#     23824473       0.00      0.00      0.00         6
#     24493444       0.00      0.00      0.00         5
#     25110766       0.00      0.00      0.00         2
#     25278162       0.00      0.00      0.00         2
#     25714995       0.00      0.00      0.00         3
#     26714969       1.00      0.50      0.67         4
#     26726405       0.00      0.00      0.00         3
#     28965410       0.00      0.00      0.00         4
#     30524469       0.00      0.00      0.00         1
#     33336411       0.00      0.00      0.00         1
#     35296740       0.00      0.00      0.00         1
#     38599049       0.00      0.00      0.00         3
#     44682227       0.00      0.00      0.00         2
#     48759730       0.00      0.00      0.00         1
#     49494636       0.00      0.00      0.00         3
#     49498188       0.00      0.00      0.00         4
#     49935971       0.00      0.00      0.00         5
#     53254994       0.00      0.00      0.00         4
#     54274515       0.00      0.00      0.00         5
#     56710362       0.00      0.00      0.00         2
#     58082329       0.00      0.00      0.00         4
#     58328086       1.00      0.25      0.40         8
#     58742287       1.00      0.44      0.62         9
#    121721616       1.00      0.83      0.91        12
#    122764472       0.00      0.00      0.00         3
#    122764737       0.00      0.00      0.00         1
#    122769301       0.00      0.00      0.00         1
#    122776005       0.00      0.00      0.00         3
#    122777079       0.00      0.00      0.00         2
#    122786401       0.00      0.00      0.00         2
#    122856012       0.83      0.56      0.67         9
#    123805814       0.00      0.00      0.00         5
#    123883561       0.00      0.00      0.00        11
#    123883610       0.00      0.00      0.00         2
#    123902286       0.00      0.00      0.00         1
#    123927094       0.00      0.00      0.00         8
#    123932889       0.00      0.00      0.00         2
#    123942253       0.00      0.00      0.00         2
#    124254528       0.00      0.00      0.00         1
#    124254625       0.00      0.00      0.00         4
#    124267813       0.00      0.00      0.00         2
#    124277139       0.00      0.00      0.00         1
#    124336576       0.00      0.00      0.00         2
#    124545319       0.00      0.00      0.00         2
#    124606420       0.00      0.00      0.00         4
#    124606451       0.00      0.00      0.00         2
#    124632457       0.00      0.00      0.00         2
#    124633843       0.00      0.00      0.00         1
#    124691773       0.00      0.00      0.00         2
#    124721429       0.00      0.00      0.00         4
#    124834949       0.00      0.00      0.00         2
#    125542311       0.00      0.00      0.00         2
#    125558054       0.00      0.00      0.00         1
#    125567129       0.00      0.00      0.00         5
#    125580066       0.00      0.00      0.00         2
#    125581520       0.00      0.00      0.00         1
#    125751655       0.00      0.00      0.00         3
#    125771101       0.00      0.00      0.00         5
#    127487870       0.00      0.00      0.00         2
#    127901561       0.00      0.00      0.00         5
#    132843807       0.00      0.00      0.00         2
#    133047472       0.00      0.00      0.00         2
#    133401572       0.00      0.00      0.00         3
#    133402413       0.00      0.00      0.00         2
#    133940428       1.00      0.20      0.33         5
#    133951720       0.00      0.00      0.00         3
#    133953695       0.00      0.00      0.00         1
#    136736656       0.00      0.00      0.00         5
#    138176095       0.45      1.00      0.62        79
#    138543939       0.00      0.00      0.00         7
#    139354017       1.00      0.86      0.92        14
#    139669159       0.00      0.00      0.00         1
#    140026718       0.00      0.00      0.00         4
#    140027109       0.00      0.00      0.00         3
#    140451774       1.00      0.20      0.33         5
#    140524677       1.00      0.67      0.80         3
#    140544215       1.00      0.64      0.78        14
#    141351006       0.00      0.00      0.00         1
#    142336314       0.00      0.00      0.00         4
#    143254185       0.00      0.00      0.00         1
#    143471294       0.00      0.00      0.00         6
#    143678129       0.00      0.00      0.00         2
#    143679284       0.00      0.00      0.00         1
#    144542015       1.00      0.38      0.55         8
#    144542026       0.00      0.00      0.00         3
#
#     accuracy                           0.32      1065
#    macro avg       0.14      0.10      0.10      1065
# weighted avg       0.28      0.32      0.24      1065
# C:\Users\gog10\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\gog10\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\gog10\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Evaluate model
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values

precision = precision_score(y_test, predictions, average='micro', zero_division=0)
print('Precision score: {0:0.2f}'.format(precision))

recall = recall_score(y_test, predictions, average='micro', zero_division=0)
print('Recall score: {0:0.2f}'.format(recall))

f1 = f1_score(y_test, predictions, average='micro', zero_division=0)
print('f1 score: {0:0.2f}'.format(recall))
# Out:
# Precision score: 0.32
# Recall score: 0.32
# f1 score: 0.32
