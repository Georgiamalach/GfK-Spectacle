# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import log_loss, roc_auc_score, recall_score, precision_score, average_precision_score, f1_score, classification_report, accuracy_score, plot_roc_curve, plot_precision_recall_curve, plot_confusion_matrix
import nltk
from nltk import word_tokenize
import re
from sklearn import feature_extraction, feature_selection, model_selection, naive_bayes, pipeline, manifold, preprocessing
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_selection import SelectKBest, f_classif, chi2
from sklearn.naive_bayes import MultinomialNB

# %%
data = pd.read_excel(r"C:\Users\gog10\GfK_spectacle_lenses_data.xlsx")

# %%
#Replace null values in the data
data.loc[data['main_text'].isnull(), 'main_text'] = 'Not Known'
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3549 entries, 0 to 3548
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   item_id         3549 non-null   int64
#  1   main_text       3549 non-null   object
#  2   country_name    3549 non-null   object
#  3   retailer_pg     3549 non-null   object
#  4   mdm_brand_text  3549 non-null   object
#  5   mdm_model_text  3549 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 166.5+ KB

# %%
#Get counts for item_id - assess if it can be split into categorical data
data['item_id'].value_counts()
# Out:
# 82981040     290
# 138176095    226
# 87099837     116
# 88210952      71
# 79429232      51
#             ...
# 81343196       5
# 122769301      5
# 124336576      5
# 119795873      5
# 64840970       5
# Name: item_id, Length: 260, dtype: int64

# %%
#Get counts for retailer_pg  - messy data so needs to be processed first
data['retailer_pg'].value_counts()
# Out:
# GLA                                 1278
# CRISTALES                            900
# LENTES                               304
# LENTE                                177
# UNASSIGNED                           168
# LENTES OFTALMICAS                    124
# LENTE|ORGANICA|PROGRESIVA             83
# LENTE|ORGANICA|MONOFOCAL              80
# LENTES//ORGANICA MONOFOCAL            64
# LENTES//ORGANICA PROGRESIVA           40
# ?253                                  31
# LENTES ORGANICA MONOFOCAL             30
# SF06                                  30
# LENTE|ORGANICA PROGRESIVA             28
# LENTE|ORGANICA MONOFOCAL              26
# VIDRES                                25
# LENTES|ORGANICA MONOFOCAL             24
# LENTES OFTÂŒMICAS                     21
# LENTES/CRISTALES                      19
# LENTES|ORGANICA PROGRESIVA            13
# MONOFOCAL                             12
# LENTES ORGANICA PROGRESIVA            11
# PROGRESIVO                            10
# 722803 - LENTES PROMOCION              6
# LENTES OFTÁLMICAS                      5
# LENTES//MONOFOCAL//ORGÁNICA            5
# LENTE|MONOFOCAL                        5
# LENTE|PROGRESIVA                       4
# LENTE|MINERAL|MONOFOCAL                4
# LENTES//PROGRESIVA//ORGÁNICA           4
# 722802 - LENTES ECI                    3
# 722801 - LENTES                        2
# LENTES//MINERAL MONOFOCAL              2
# LENTES//ORGANICA BIFOCAL               1
# LOFT/ESTD/MONO/ORGAN                   1
# LENTE|MINERAL|PROGRESIVA               1
# LENTE|ORGANICA BIFOCAL                 1
# MONT                                   1
# LENTES//POLICARBONATO PROGRESIVA       1
# LENTE|ORGANICA|BIFOCAL                 1
# GL                                     1
# SUPLEMENTO|SOL|.                       1
# ||PROGRESIVA                           1
# LOFT/ESTD/PROG/ORGAN                   1
# Name: retailer_pg, dtype: int64

# %%
#Get counts for main_text - messy data so needs to be processed first
data['main_text'].value_counts()
# Out:
# BALANSIS 1.60 (RX)                                                    24
# ID1.60LIFESTL3IURBAN(RX)                                              22
# HILUX 1.60 EYAS (RX)                                                  13
# ?ROD  L2LK?  -  ?ROD  SU?                                             12
# ZEISS ES SPH 1.6  -  LOTUTEC                                          12
#                                                                       ..
# ?ESS  GFB100?  -  ?ESS  676?                                           1
# ?EO  GFB540?  -  ?EO  676?                                             1
# ?ES-  G8E634?  -  ?ES-  675?                                           1
# ?NIKA 113?  -  ?NIKA 199?                                              1
# CRISTALES 34244 MI LIFESTYLE 3I 1.5 BC PROGRESIVO ORGÁNICO HVLL BC     1
# Name: main_text, Length: 2815, dtype: int64

# %%
#Counts by country
country_count = data['country_name'].value_counts()
country_count
# Out:
# SPAIN      2270
# GERMANY    1279
# Name: country_name, dtype: int64

# %%
#Plot counts by country
sns.set(style="darkgrid")
sns.barplot(x = country_count.index, y = country_count.values, alpha=0.9)
plt.title('Frequency Distribution of Countries')
plt.ylabel('Frequency', fontsize=12)
plt.xlabel('Country', fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14404/49760246.py in <module>
#       1 #Plot counts by country
#       2 sns.set(style="darkgrid")
# ----> 3 sns.barplot(x = country_count.index, y = country_count.values, alpha=0.9)
#       4 plt.title('Frequency Distribution of Countries')
#       5 plt.ylabel('Frequency', fontsize=12)
#
# NameError: name 'country_count' is not defined

# %%
#Denote country name into numerical categories
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
categorical_col = ['country_name']
for col in categorical_col:
    data[col] = l.fit_transform(data[col])
data.head()
# Out:
#      item_id                 main_text  country_name retailer_pg  \
# 0  138176095  ID1.60LIFESTL3IURBAN(RX)             1   CRISTALES
# 1  138176095  ID1.60LIFESTL3IURBAN(RX)             1   CRISTALES
# 2  138176095  ID1.60LIFESTL3IURBAN(RX)             1   CRISTALES
# 3  138176095  ID1.60LIFESTL3IURBAN(RX)             1   CRISTALES
# 4  138176095  ID1.60LIFESTL3IURBAN(RX)             1   CRISTALES
#
#   mdm_brand_text                 mdm_model_text
# 0           HOYA  HOYALUX ID LIFESTYLE 3-I HVLL
# 1           HOYA  HOYALUX ID LIFESTYLE 3-I HVLL
# 2           HOYA  HOYALUX ID LIFESTYLE 3-I HVLL
# 3           HOYA  HOYALUX ID LIFESTYLE 3-I HVLL
# 4           HOYA  HOYALUX ID LIFESTYLE 3-I HVLL

# %%
#Try splitting dataframe into countries
data_germany = data[data['country_name'] == 0]
data_spain = data[data['country_name'] == 1]
data_spain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2270 entries, 0 to 3548
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   item_id         2270 non-null   int64
#  1   main_text       2270 non-null   object
#  2   country_name    2270 non-null   int32
#  3   retailer_pg     2270 non-null   object
#  4   mdm_brand_text  2270 non-null   object
#  5   mdm_model_text  2270 non-null   object
# dtypes: int32(1), int64(1), object(4)
# memory usage: 115.3+ KB

# %%
#Check retailer_pg counts for Spain only
data_spain['retailer_pg'].value_counts()
# Out:
# CRISTALES                           900
# LENTES                              304
# LENTE                               177
# UNASSIGNED                          168
# LENTES OFTALMICAS                   124
# LENTE|ORGANICA|PROGRESIVA            83
# LENTE|ORGANICA|MONOFOCAL             80
# LENTES//ORGANICA MONOFOCAL           64
# LENTES//ORGANICA PROGRESIVA          40
# ?253                                 31
# LENTES ORGANICA MONOFOCAL            30
# SF06                                 30
# LENTE|ORGANICA PROGRESIVA            28
# LENTE|ORGANICA MONOFOCAL             26
# VIDRES                               25
# LENTES|ORGANICA MONOFOCAL            24
# LENTES OFTÂŒMICAS                    21
# LENTES/CRISTALES                     19
# LENTES|ORGANICA PROGRESIVA           13
# MONOFOCAL                            12
# LENTES ORGANICA PROGRESIVA           11
# PROGRESIVO                           10
# 722803 - LENTES PROMOCION             6
# LENTE|MONOFOCAL                       5
# LENTES//MONOFOCAL//ORGÁNICA           5
# LENTES OFTÁLMICAS                     5
# LENTE|MINERAL|MONOFOCAL               4
# LENTES//PROGRESIVA//ORGÁNICA          4
# LENTE|PROGRESIVA                      4
# 722802 - LENTES ECI                   3
# 722801 - LENTES                       2
# LENTES//MINERAL MONOFOCAL             2
# LENTE|ORGANICA BIFOCAL                1
# MONT                                  1
# LOFT/ESTD/PROG/ORGAN                  1
# LENTE|MINERAL|PROGRESIVA              1
# LENTES//ORGANICA BIFOCAL              1
# LOFT/ESTD/MONO/ORGAN                  1
# LENTE|ORGANICA|BIFOCAL                1
# SUPLEMENTO|SOL|.                      1
# ||PROGRESIVA                          1
# LENTES//POLICARBONATO PROGRESIVA      1
# Name: retailer_pg, dtype: int64

# %%
#Check retailer_pg counts for Germany only
data_germany['retailer_pg'].value_counts()
# Out:
# GLA    1278
# GL        1
# Name: retailer_pg, dtype: int64

# %%
#Use Global model
#Delete columns not needed for model
data.drop(['country_name', 'mdm_brand_text', 'mdm_model_text'], axis = 'columns', inplace=True)

# %%
data.head()
# Out:
#      item_id                 main_text retailer_pg
# 0  138176095  ID1.60LIFESTL3IURBAN(RX)   CRISTALES
# 1  138176095  ID1.60LIFESTL3IURBAN(RX)   CRISTALES
# 2  138176095  ID1.60LIFESTL3IURBAN(RX)   CRISTALES
# 3  138176095  ID1.60LIFESTL3IURBAN(RX)   CRISTALES
# 4  138176095  ID1.60LIFESTL3IURBAN(RX)   CRISTALES

# %%
# rename columns for model
data = data.rename(columns={"item_id":"y", "main_text":"text", "retailer_pg":"pg"})
data
# Out:
#               y                                               text         pg
# 0     138176095                           ID1.60LIFESTL3IURBAN(RX)  CRISTALES
# 1     138176095                           ID1.60LIFESTL3IURBAN(RX)  CRISTALES
# 2     138176095                           ID1.60LIFESTL3IURBAN(RX)  CRISTALES
# 3     138176095                           ID1.60LIFESTL3IURBAN(RX)  CRISTALES
# 4     138176095                           ID1.60LIFESTL3IURBAN(RX)  CRISTALES
# ...         ...                                                ...        ...
# 3544   25278162  CRISTALES 34212 MI MF XPERIENCE 1.5 BASIC HV P...  CRISTALES
# 3545  115519055  CRISTALES 34186 MI HILUX 1.6 SHV FAB MONOFOCAL...  CRISTALES
# 3546  112904161  CRISTALES 34317 NULUX ACTIVE TF 1.5 HV ORGÁNIC...  CRISTALES
# 3547  138176095  CRISTALES 34244 MI LIFESTYLE 3I 1.5 HVLL BC PR...  CRISTALES
# 3548  138176095  CRISTALES 34244 MI LIFESTYLE 3I 1.5 BC PROGRES...  CRISTALES
#
# [3549 rows x 3 columns]

# %%
#list of stop words from nltk
lst_stopwords = nltk.corpus.stopwords.words("english")
lst_stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
#create a function to remove these stop words, remove certain characters, stem the text and lemmatize the text in main text
'''
Preprocess a string.
:parameter
    :param text: string - name of column containing text
    :param lst_stopwords: list - list of stopwords to remove
    :param flg_stemm: bool - whether stemming is to be applied
    :param flg_lemm: bool - whether lemmitisation is to be applied
:return
    cleaned text
'''
def preprocess_text(text, flg_stemm=False, flg_lemm=True, lst_stopwords=None):
    ## clean (remove punctuations and characters and then strip)
    text = re.sub(r'[^\w\s]', '', str(text).strip())
            
    ## Tokenize (convert from string to list)
    lst_text = text.split()
    
    ## remove Stopwords
    if lst_stopwords is not None:
        lst_text = [word for word in lst_text if word not in 
                    lst_stopwords]
                
    ## Stemming (remove -ing, -ly, ...)
    if flg_stemm == True:
        ps = nltk.stem.porter.PorterStemmer()
        lst_text = [ps.stem(word) for word in lst_text]
                
    ## Lemmatisation (convert the word into root word)
    if flg_lemm == True:
        lem = nltk.stem.wordnet.WordNetLemmatizer()
        lst_text = [lem.lemmatize(word) for word in lst_text]
            
    ## back to string from list
    text = " ".join(lst_text)
    return text

# %%
#create a function to remove these stop words, remove certain characters, stem the text and lemmatize the text for pg
'''
Preprocess a string.
:parameter
    :param text: string - name of column containing text
    :param lst_stopwords: list - list of stopwords to remove
    :param flg_stemm: bool - whether stemming is to be applied
    :param flg_lemm: bool - whether lemmitisation is to be applied
:return
    cleaned text
'''
def preprocess_pg(pg, flg_stemm=False, flg_lemm=True, lst_stopwords=None):
    ## clean (remove punctuations and characters and then strip)
    pg = re.sub(r'[^\w\s]', '', str(pg).strip())
            
    ## Tokenize (convert from string to list)
    lst_pg = pg.split()
    ## remove Stopwords
    if lst_stopwords is not None:
        lst_pg = [word for word in lst_pg if word not in 
                    lst_stopwords]
                
    ## Stemming (remove -ing, -ly, ...)
    if flg_stemm == True:
        ps = nltk.stem.porter.PorterStemmer()
        lst_pg = [ps.stem(word) for word in lst_pg]
                
    ## Lemmatisation (convert the word into root word)
    if flg_lemm == True:
        lem = nltk.stem.wordnet.WordNetLemmatizer()
        lst_pg = [lem.lemmatize(word) for word in lst_pg]
            
    ## back to string from list
    pg = " ".join(lst_pg)
    return pg

# %%
#Apply the function for text
data["text_clean"] = data["text"].apply(lambda x: 
          preprocess_text(x, flg_stemm=False, flg_lemm=True, 
          lst_stopwords=lst_stopwords))

# %%
#Apply the function for pg
data["pg_clean"] = data["pg"].apply(lambda x: 
          preprocess_pg(x, flg_stemm=False, flg_lemm=True, 
          lst_stopwords=lst_stopwords))
data.head()
# Out:
#            y                      text         pg             text_clean  \
# 0  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES  ID160LIFESTL3IURBANRX
# 1  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES  ID160LIFESTL3IURBANRX
# 2  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES  ID160LIFESTL3IURBANRX
# 3  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES  ID160LIFESTL3IURBANRX
# 4  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES  ID160LIFESTL3IURBANRX
#
#     pg_clean
# 0  CRISTALES
# 1  CRISTALES
# 2  CRISTALES
# 3  CRISTALES
# 4  CRISTALES

# %%
#Combine text and pg
data["text_combined"] = data.text_clean + data.pg_clean
y = data['y']
data.head()
# Out:
#            y                      text         pg             text_clean  \
# 0  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES  ID160LIFESTL3IURBANRX
# 1  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES  ID160LIFESTL3IURBANRX
# 2  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES  ID160LIFESTL3IURBANRX
# 3  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES  ID160LIFESTL3IURBANRX
# 4  138176095  ID1.60LIFESTL3IURBAN(RX)  CRISTALES  ID160LIFESTL3IURBANRX
#
#     pg_clean                   text_combined
# 0  CRISTALES  ID160LIFESTL3IURBANRXCRISTALES
# 1  CRISTALES  ID160LIFESTL3IURBANRXCRISTALES
# 2  CRISTALES  ID160LIFESTL3IURBANRXCRISTALES
# 3  CRISTALES  ID160LIFESTL3IURBANRXCRISTALES
# 4  CRISTALES  ID160LIFESTL3IURBANRXCRISTALES

# %%
# split dataset
data_train, data_test = model_selection.train_test_split(data, test_size=0.3)
# get target
y_train = data_train["y"].values
y_test = data_test["y"].values

# %%
#TfIdf, fit and transform, use SelectKBest
vectorizer = feature_extraction.text.TfidfVectorizer(max_features=None, ngram_range=(1,1))
texts = data_train["text_combined"]
x_train = vectorizer.fit_transform(texts)
selector = SelectKBest(chi2, k=min(50, x_train.shape[1]))
selector.fit(x_train, y_train)
x_train = selector.transform(x_train)
dic_vocabulary = vectorizer.vocabulary_

# %%
dic_vocabulary
# Out:
# {'zeiss': 2180,
#  'officelens': 1640,
#  'plus': 1749,
#  'room': 1892,
#  '153': 175,
#  'blueprotect': 908,
#  '6570': 609,
#  '0unassigned': 77,
#  'cristales': 980,
#  '11413': 109,
#  'estelux': 1145,
#  '16': 185,
#  'hmccristales': 1282,
#  'ormix': 1674,
#  'crizal': 986,
#  'prevencia': 1790,
#  'estoc': 1146,
#  '75075275lente': 729,
#  'rod': 1873,
#  'l2lk': 1423,
#  'sugla': 2015,
#  'varilux': 2121,
#  'comfort': 962,
#  '3o': 420,
#  'sun': 2017,
#  'color': 954,
#  'cris': 978,
#  'verde': 2124,
#  'clentes': 944,
#  'ro': 1871,
#  'i3iky2': 1341,
#  'eyezen': 1166,
#  'orma': 1672,
#  '15': 167,
#  'rx': 1900,
#  'forte': 1186,
#  'uv': 2111,
#  'sin': 1968,
#  'epsmonofocal': 1112,
#  'rh': 1862,
#  '1162': 115,
#  '090gla': 71,
#  'einst': 1088,
#  'f360': 1169,
#  'lineis': 1467,
#  'ese': 1123,
#  '675gla': 629,
#  '98': 810,
#  'eps': 1104,
#  'active': 818,
#  '085': 68,
#  'eyecode': 1164,
#  'prevenciacristales': 1791,
#  'trans': 2076,
#  '75000050': 697,
#  'grislentes': 1238,
#  '350': 406,
#  'ess': 1140,
#  'stockcristales': 2004,
#  'lente': 1433,
#  'essilor': 1142,
#  'wow': 2153,
#  'initial': 1403,
#  '04': 40,
#  'organica': 1661,
#  'monofocallente': 1571,
#  'vidres': 2130,
#  'neo': 1612,
#  'sport': 1984,
#  'polar': 1757,
#  'sd': 1926,
#  '0a': 74,
#  '2vidres': 363,
#  '160': 186,
#  'hvpcristales': 1328,
#  'organico': 1662,
#  'progresivo': 1816,
#  'design': 1047,
#  'transitions': 2079,
#  'xtra': 2173,
#  'epslentescristales': 1111,
#  '880631': 786,
#  'liberty': 1459,
#  'ne': 1609,
#  'short': 1946,
#  'ojo': 1648,
#  'der': 1043,
#  'esf': 1126,
#  '275': 332,
#  'cil': 936,
#  '05': 52,
#  'eje': 1090,
#  '95': 803,
#  'adic': 823,
#  '225': 281,
#  'diam': 1055,
#  '65lentes': 620,
#  'progresiva': 1810,
#  'mono': 1565,
#  '174monofocalorganico0scuvsin': 235,
#  'colorlentes': 958,
#  'oftalmicas': 1643,
#  '11560': 112,
#  '000': 0,
#  '0000': 1,
#  '0250': 30,
#  'indo': 1382,
#  'easy': 1082,
#  'max': 1525,
#  'rvd': 1899,
#  'indofincristales': 1385,
#  '752540': 743,
#  'xclusive': 2156,
#  '4d': 476,
#  'stylis': 2013,
#  '167': 195,
#  'eye': 1163,
#  'protect': 1829,
#  'system': 2050,
#  '525': 495,
#  '075': 64,
#  '90': 792,
#  '76450': 759,
#  'id': 1347,
#  'lifestyle': 1464,
#  'urban': 2105,
#  'progresivalente': 1813,
#  'i3gk': 1340,
#  'nugla': 1634,
#  '7sy': 770,
#  '6437': 569,
#  'osgla': 1679,
#  '34188': 399,
#  '090': 70,
#  '0050': 9,
#  'airwear': 828,
#  'kids': 1415,
#  'prebvenciacristales': 1771,
#  'impression': 1375,
#  'rodensugla': 1876,
#  '879540': 785,
#  '125': 130,
#  'monofocal': 1568,
#  'sphisch': 1983,
#  'eo': 1100,
#  '505gla': 482,
#  'indofin': 1384,
#  'es': 1116,
#  'indosolunif': 1397,
#  'durcap': 1072,
#  '70': 646,
#  'marrón': 1522,
#  'tonod': 2072,
#  'org': 1656,
#  'tratcéfir': 2082,
#  'cara': 927,
#  'cóncavacristales': 1017,
#  'czl': 1007,
#  '10680': 94,
#  'czlgla': 1008,
#  '30': 367,
#  '6065': 556,
#  'sapphire': 1918,
#  'precalibradocristales': 1776,
#  'indopolar': 1391,
#  'gris': 1231,
#  '70cristales': 675,
#  '2a': 355,
#  'activa_rvd': 817,
#  'natural10': 1605,
#  '6253': 565,
#  'precissuperb': 1782,
#  'platinum': 1738,
#  '60x50': 563,
#  'duravision': 1069,
#  '5cristales': 538,
#  '108': 97,
#  'hilux': 1273,
#  'eyas': 1160,
#  'orgánicocristales': 1667,
#  'precal': 1773,
#  'shv': 1949,
#  'con': 964,
#  'prismalenteorganica': 1801,
#  'stocklenteorganicamonofocal': 2006,
#  '55100350': 507,
#  'marrolentes': 1513,
#  '2ro': 361,
#  'm2lsch': 1504,
#  'sngla': 1974,
#  'czy': 1013,
#  '6950': 639,
#  'hmgla': 1292,
#  '4zu': 478,
#  '13238': 141,
#  'ltgla': 1500,
#  '6594': 616,
#  '180': 243,
#  '0200': 25,
#  '150': 168,
#  'hoylifestyle': 1308,
#  'indoor': 1386,
#  '16cristales': 204,
#  'modelo': 1563,
#  'prog': 1804,
#  'sol': 1975,
#  'personalizado': 1718,
#  'ipseo': 1405,
#  '174': 231,
#  'algénero': 833,
#  'progmaterial': 1807,
#  'organtirreflejante': 1663,
#  'noantirrayado': 1627,
#  'nocolor': 1628,
#  'ptdmcfotocromáticocristales': 1834,
#  'vlx': 2134,
#  'ilikia': 1372,
#  'fit': 1177,
#  '16lenteorganicaprogresiva': 209,
#  'life': 1460,
#  'style': 2012,
#  'indoorlenteorganicaprogresiva': 1388,
#  'perfalit': 1713,
#  'siks': 1962,
#  'rodgla': 1877,
#  '8763': 784,
#  '045': 45,
#  '0275': 31,
#  '200': 268,
#  '15cristales': 180,
#  '10938': 99,
#  '025': 29,
#  '0100': 16,
#  '0300': 34,
#  'hoy': 1300,
#  '1cristales': 259,
#  '2761': 333,
#  'griscristales': 1234,
#  'gs': 1246,
#  'classic': 941,
#  'cze': 1002,
#  'individual': 1381,
#  'lotutecgla': 1474,
#  'precalibrado': 1775,
#  'digitalcristales': 1062,
#  'czn': 1009,
#  'czngla': 1010,
#  'nl150active053trueformrxcristales': 1622,
#  'az6540': 863,
#  'esegla': 1124,
#  '1122': 105,
#  'rhgla': 1865,
#  '69': 637,
#  'new': 1613,
#  'generic': 1205,
#  'eliptico': 1091,
#  'orgãšnicocristales': 1670,
#  '13103': 138,
#  'czygla': 1014,
#  'lentesbbgrunem': 1436,
#  'mineral': 1549,
#  '17': 227,
#  'diamslentes': 1058,
#  'monoorganico': 1579,
#  'as': 856,
#  '75050300lentes': 720,
#  'superfin': 2030,
#  'indosol': 1393,
#  'basic': 879,
#  'stock': 2003,
#  '65cristales': 617,
#  'cag100': 924,
#  'lentes': 1434,
#  'promocion253': 1824,
#  'telegrand': 2059,
#  'fotocrom': 1190,
#  'al': 831,
#  'marrongénero': 1517,
#  'monomaterial': 1577,
#  'sicolor': 1957,
#  'fotocromáticocristales': 1192,
#  'l2mk': 1424,
#  'evolta': 1150,
#  'tintlenteorganicamonofocal': 2065,
#  'sei': 1930,
#  '74zs': 694,
#  'seiko': 1931,
#  'superresistantcoatgla': 2036,
#  '7580': 750,
#  'dag': 1024,
#  'c29000': 921,
#  'daggla': 1025,
#  '2cz': 357,
#  '6927': 638,
#  '2czgla': 358,
#  'globe': 1220,
#  '75cristales': 751,
#  'cr39gla': 974,
#  '19851': 256,
#  '005': 8,
#  '0025': 6,
#  '33429': 386,
#  '095': 73,
#  '0075': 12,
#  '598100': 537,
#  'uvgla': 2116,
#  'syn': 2045,
#  '7489': 692,
#  'syngla': 2047,
#  'según': 1929,
#  'muestra': 1589,
#  'degradadocristales': 1038,
#  '7sygla': 771,
#  'sólo': 2055,
#  'diferencia': 1060,
#  'prevencialentes': 1792,
#  'actv': 820,
#  'eprtsys': 1102,
#  '146': 162,
#  '0002cristales': 2,
#  'hoya': 1301,
#  '16rx': 220,
#  '65': 573,
#  'cilindro': 937,
#  'nl150active088trueformrxcristales': 1624,
#  'fmpt': 1182,
#  'rogla': 1887,
#  'cza': 998,
#  'czagla': 999,
#  'lutina': 1501,
#  'resonas': 1858,
#  'sps': 1986,
#  '0016cristales': 5,
#  '6414': 568,
#  '250': 298,
#  'lifes': 1461,
#  'relaxus': 1857,
#  '0160cristales': 22,
#  '485100': 470,
#  'physiotints': 1729,
#  'marron': 1514,
#  'izq': 1410,
#  '175': 238,
#  '7075lentesorganica': 671,
#  '16st': 226,
#  'hardlenteorganicamonofocal': 1255,
#  'sy': 2043,
#  '7525': 741,
#  'sygla': 2044,
#  '2es': 359,
#  '318100': 376,
#  '2esgla': 360,
#  '65025250lentes': 588,
#  'p12lenteorganica': 1692,
#  '2649': 315,
#  'gf4634': 1207,
#  'oftâœmicas': 1646,
#  'españa': 1131,
#  'sa': 1915,
#  'confort': 967,
#  'progresivos': 1817,
#  '1600': 187,
#  'sph': 1982,
#  '16gla': 205,
#  'id160lifestl3urbanrxprogresivosorganico1600hvllsin': 1366,
#  'syz': 2054,
#  '6956': 640,
#  '772': 762,
#  '105': 91,
#  'uvcristales': 2114,
#  '15lenteorganicamonofocal': 182,
#  'hoyalux': 1303,
#  'pas14': 1705,
#  '7500lente': 707,
#  'nik': 1615,
#  '736s': 689,
#  '270gla': 325,
#  'flint': 1180,
#  'lab': 1427,
#  '4vidres': 477,
#  'sbgla': 1923,
#  'cz': 996,
#  '10042': 80,
#  'de': 1032,
#  '16as': 203,
#  'degradadogénero': 1040,
#  'ptdncfotocromáticocristales': 1835,
#  '6445': 570,
#  'hxgla': 1334,
#  'prevenciamonofocal': 1793,
#  '226': 283,
#  '5559': 522,
#  'precision': 1780,
#  'superb': 2027,
#  'duravisioncristales': 1070,
#  'b003': 867,
#  'kra': 1421,
#  'hset': 1311,
#  'kgla': 1414,
#  '75050225lentes': 719,
#  'len': 1431,
#  '3i': 418,
#  'rxlentes': 1908,
#  'hard': 1250,
#  '1600cristales': 188,
#  'asferica': 859,
#  'uniformegénero': 2101,
#  'ptumc': 1842,
#  'uniforme': 2099,
#  'cfotocromáticocristales': 935,
#  'moah': 1561,
#  'bugla': 916,
#  '10679': 93,
#  'czgla': 1004,
#  'b001': 865,
#  'tonoc': 2070,
#  '33649': 392,
#  '030': 33,
#  'precristales': 1783,
#  'bpgla': 915,
#  '103º': 88,
#  '815540': 777,
#  '60lentesorganica': 561,
#  'vsun': 2137,
#  'altacurvaprogresivosorganico1600crizal': 835,
#  'suncon': 2018,
#  'ergo': 1115,
#  'nikat': 1617,
#  'superbreitbandentspiegelunggla': 2028,
#  '136100': 150,
#  'antifatigue': 845,
#  'hmclente': 1285,
#  '2719': 328,
#  '901524': 795,
#  '325': 377,
#  'sundegradadoprogresivo': 2020,
#  'vx': 2138,
#  'physio': 1726,
#  'binoc': 897,
#  'xperio': 2167,
#  '65000175lentes': 579,
#  '3es': 416,
#  '120100': 123,
#  '174monofocalorganico1740scc': 237,
#  'uvsin': 2118,
#  'rog': 1885,
#  'p2lkb2': 1698,
#  '1982': 255,
#  '0125': 18,
#  '1167': 116,
#  'id160lifestl3iurbanrxcristales': 1356,
#  'indf': 1378,
#  'durcapmonofocalorganico1600sin': 1078,
#  'nulux': 1635,
#  'tf': 2061,
#  '053cristales': 55,
#  'progclassic': 1805,
#  '70x60': 679,
#  'flkft': 1181,
#  '67srgla': 633,
#  'webglas': 2146,
#  'einstken': 1089,
#  'mmsgla': 1560,
#  'precisplus': 1781,
#  'photofg': 1723,
#  'silver': 1964,
#  '16637': 194,
#  '080': 67,
#  '0325': 36,
#  'cprevenciacristales': 972,
#  'rayban': 1854,
#  '70125075lentes': 656,
#  'maigla': 1506,
#  '4340': 437,
#  '80cristales': 774,
#  'msgla': 1586,
#  'shvlentesorganica': 1955,
#  '75025075lentes': 708,
#  'xl': 2161,
#  'alta': 834,
#  'curvatura': 995,
#  '8196': 779,
#  '34244': 402,
#  'mi': 1547,
#  'hvll': 1319,
#  'bc': 884,
#  'orgánico': 1666,
#  'bccristales': 885,
#  'lentesindosuperfin': 1446,
#  '70lentes': 677,
#  'curv': 993,
#  '96100050': 808,
#  'naturallenteorganicaprogresiva': 1607,
#  'g8d100': 1199,
#  '815gla': 778,
#  'ideal': 1368,
#  'lt010000266': 1477,
#  'masterlux': 1524,
#  '19': 251,
#  'ad': 821,
#  'indosf06': 1392,
#  'digital': 1061,
#  'indiv': 1379,
#  'blueprotectlenteorganicaprogresiva': 910,
#  '2866': 344,
#  '2598': 307,
#  'blancocristales': 901,
#  '13343': 142,
#  '0175': 24,
#  'rg': 1860,
#  'l2sk': 1426,
#  'progr': 1808,
#  'personaliz': 1717,
#  'booster': 912,
#  'ptdgcfotocromáticocristales': 1832,
#  '35': 405,
#  'hifi': 1270,
#  'expmonofocalmineral17sin': 1156,
#  '16progresivosorganico2000crizal': 219,
#  'id160lifestl3iindoorrxprogresivosorganico1600hvll': 1349,
#  'bcsin': 887,
#  'polarigris': 1759,
#  'back': 872,
#  '70x60cristales': 680,
#  'zsy': 2184,
#  'zsygla': 2185,
#  '3341': 385,
#  '023gla': 28,
#  '4827': 467,
#  'met': 1540,
#  'pp3700': 1768,
#  'coatgla': 949,
#  'progressuperb': 1820,
#  'platinumlenteorganicaprogresiva': 1742,
#  'nlb': 1625,
#  'hvllgla': 1322,
#  '375': 409,
#  '65lentesorganica': 621,
#  'lt100008446': 1490,
#  'zeisssf06': 2181,
#  'xtractive': 2175,
#  '2878': 346,
#  'super': 2026,
#  'etgla': 1149,
#  'ls': 1475,
#  'clarity': 938,
#  'p14': 1694,
#  'blue': 905,
#  'controllenteorganica': 968,
#  '1867': 247,
#  'zei': 2178,
#  '16progresivosorganico0hvllsin': 215,
#  'indosoluniforme': 1398,
#  '10053': 82,
#  'platinumgla': 1740,
#  'maxee': 1527,
#  'asferico': 860,
#  'hmc': 1280,
#  'stlenteorganicamonofocal': 1998,
#  'sunlentes': 2022,
#  '3023': 370,
#  '104gla': 90,
#  '954100': 806,
#  '045gla': 47,
#  'physiotinlentes': 1727,
#  '2641': 313,
#  '75x65': 754,
#  'degradadoneg': 1041,
#  'systemlentescristales': 2053,
#  '75125425lentes': 735,
#  '6570cristales': 610,
#  'or': 1655,
#  'xpeiro': 2162,
#  '6833': 634,
#  '165': 192,
#  '0475': 49,
#  'asf': 858,
#  'durcapcristales': 1073,
#  'cz1': 997,
#  'xact': 2155,
#  'pasillo': 1706,
#  '11lenteorganicaprogresiva': 119,
#  '161': 190,
#  'antirreflejolenteorganicamonofocal': 846,
#  'es9': 1118,
#  '314100': 375,
#  'es9gla': 1119,
#  'naturallentes': 1608,
#  'ocupacional': 1637,
#  'pc': 1707,
#  'essilorlentes': 1143,
#  'eynoa': 1168,
#  'sensity': 1934,
#  '65000600': 585,
#  '14000': 157,
#  '6575': 613,
#  'orgcristales': 1665,
#  'stk': 1988,
#  'pack': 1700,
#  '70150050': 660,
#  'maxeemonoasf167hmcplusstmonofocalorganico1670sin': 1532,
#  'sl': 1971,
#  '60': 542,
#  'hart': 1259,
#  'set': 1936,
#  'direkt': 1063,
#  '65150450': 604,
#  '65050025lentes': 591,
#  '4521': 449,
#  'marroncristales': 1516,
#  'shvlenteorganica': 1951,
#  'rodswflhfsgla': 1878,
#  '7076': 672,
#  'cristal': 979,
#  'hvlllenteorganica': 1323,
#  '954': 805,
#  'stklentesorganica': 1992,
#  'eselux': 1125,
#  'balansis': 874,
#  'hv': 1313,
#  'solar': 1976,
#  'czegla': 1003,
#  'orlite': 1671,
#  'shmc': 1942,
#  '174cristales': 232,
#  '6492': 572,
#  'mpgla': 1582,
#  '65x55': 623,
#  'light': 1465,
#  '3d': 415,
#  'c28': 920,
#  'eyas160': 1161,
#  '77100100lente': 761,
#  '75': 695,
#  'monosuperb': 1580,
#  'blueprotectlenteorganicamonofocal': 909,
#  '934': 802,
#  '174monofocalorganico0shmcsin': 236,
#  '7075': 668,
#  '10045': 81,
#  'rxlenteorganica': 1905,
#  '5542': 521,
#  '523gla': 491,
#  'id160lifestl3outdoorrxprogresivosorganico1600hvllcon': 1359,
#  'c60': 922,
#  'hardhvlgla': 1253,
#  'ormx': 1677,
#  'epsmonofocalorganico2sin': 1113,
#  '105gla': 92,
#  'com': 960,
#  'sho': 1945,
#  '167lenteorganicaprogresiva': 201,
#  'mtzgla': 1588,
#  '1299': 134,
#  'superdiafal': 2029,
#  'tcristales': 2057,
#  'l2mpb2': 1425,
#  'pugla': 1850,
#  '11342': 108,
#  'pcristales': 1708,
#  'epslenteorganicaprogresiva': 1108,
#  'epslenteorganicamonofocal': 1107,
#  '532': 496,
#  '0400': 42,
#  'dao': 1027,
#  'w21000': 2144,
#  'daogla': 1028,
#  '5080': 484,
#  'sips': 1969,
#  'rok': 1888,
#  'flhfs': 1178,
#  'rokgla': 1889,
#  '110º': 104,
#  'trsmarrón': 2088,
#  'céfirlentes': 1015,
#  'i3gh': 1339,
#  'rxcristales': 1903,
#  'g8j634': 1201,
#  '8734': 783,
#  '0225': 27,
#  '0425': 43,
#  'maxxee': 1534,
#  'arlcristales': 852,
#  'hc4': 1260,
#  'hardhvagla': 1252,
#  'en2': 1093,
#  'enrarpgla': 1099,
#  'shamir': 1940,
#  'superlite': 2035,
#  '55150450lente': 513,
#  '428642': 435,
#  '6551': 607,
#  '2909': 349,
#  'dpgla': 1065,
#  'impr': 1374,
#  'myop': 1595,
#  'xs': 2171,
#  '75lentesorganica': 753,
#  'lt100013027': 1499,
#  'comf': 961,
#  'essilorsf06': 1144,
#  'ao': 847,
#  'aogla': 848,
#  '13501gla': 149,
#  '5ru': 539,
#  '5rugla': 540,
#  '81': 776,
#  '434634': 439,
#  'id160lifestl3urbanrxcristales': 1362,
#  'cag464': 925,
#  '65000100lentes': 576,
#  '12379': 128,
#  'ptumcfotocromáticocristales': 1843,
#  '1859': 246,
#  'fs': 1197,
#  'rmv': 1868,
#  'id160lifestl3indoorrxcristales': 1351,
#  'czs': 1011,
#  '6399': 567,
#  'platinumvidres': 1745,
#  'fab': 1171,
#  'arlentes': 854,
#  'cosmolit': 969,
#  'hv99': 1314,
#  'bifocallente': 894,
#  '2831': 340,
#  'øcristales': 2187,
#  'lite': 1468,
#  'sv': 2042,
#  '65253': 606,
#  '155º': 179,
#  '100': 79,
#  '2a16vidres': 356,
#  'wet': 2148,
#  'n21b20gla': 1598,
#  'anfertigung': 844,
#  'diatan': 1059,
#  'hdrgla': 1266,
#  'ptugdfotocromáticocristales': 1839,
#  'optima': 1654,
#  '11': 102,
#  'glenteorganicamonofocal': 1217,
#  '12636': 131,
#  '26639': 318,
#  'cprevencia': 971,
#  '2x1cristales': 366,
#  '65000125': 577,
#  'essgla': 1141,
#  '70150100': 661,
#  '12703': 133,
#  '155': 178,
#  '0550': 57,
#  '901145': 793,
#  'supra': 2039,
#  '75000225lente': 703,
#  'mf': 1544,
#  'ar': 851,
#  'top': 2074,
#  'solidoslente': 1978,
#  'esn': 1128,
#  '337100': 394,
#  'esngla': 1129,
#  'xes': 2159,
#  'xesgla': 2160,
#  'junior': 1412,
#  'rotura': 1894,
#  'tlentes': 2067,
#  'progindiv2': 1806,
#  '65000250lentes': 582,
#  'ron': 1890,
#  'sikhs': 1961,
#  'rongla': 1891,
#  '217631': 278,
#  '4755': 459,
#  'easymax': 1083,
#  'natural': 1604,
#  'clear': 942,
#  'ir': 1407,
#  '7075cristales': 669,
#  'xperioprogresivo': 2168,
#  'indosoldegr': 1394,
#  'degradado': 1037,
#  'tonoccristales': 2071,
#  '65000150lentes': 578,
#  '487100': 473,
#  '70lentesorganica': 678,
#  '524100': 492,
#  '259gla': 308,
#  'grisverde': 1241,
#  '74': 691,
#  'base': 878,
#  'especial': 1132,
#  'gmonofocalorganico1500crome': 1221,
#  'sunsin': 2023,
#  'aktion': 830,
#  'lg': 1458,
#  'hld': 1277,
#  'enrargla': 1098,
#  '13370': 143,
#  '55200525lente': 516,
#  'uvprogresivo': 2117,
#  '130': 136,
#  'indosoldegradado': 1395,
#  'bidegradado': 889,
#  'tono': 2068,
#  'da': 1020,
#  'cotascristales': 970,
#  'xze': 2176,
#  'xzegla': 2177,
#  '486100': 471,
#  'iicristales': 1371,
#  '95º': 807,
#  '25': 297,
#  '70000750lentes': 648,
#  '121100': 126,
#  'xtrack': 2174,
#  '1523': 174,
#  'icrmaminø7bifocalmineral1523sin': 1345,
#  '167lentemonofocal': 199,
#  '6eu': 643,
#  'criza': 985,
#  '13435': 145,
#  'pulit': 1851,
#  'xrogla': 2170,
#  'vmonofocalorganico1500krypton': 2135,
#  'i2lk': 1338,
#  'ex4w0': 1151,
#  '16569': 193,
#  '0350': 38,
#  'uniformegris': 2100,
#  '85': 780,
#  '11cristales': 118,
#  'kodak': 1419,
#  'unique': 2103,
#  'progresivalenteorganicaprogresiva': 1814,
#  'epslenteprogresiva': 1109,
#  '11584': 113,
#  'msa': 1584,
#  'zk3100': 2183,
#  'setgla': 1937,
#  'confor': 966,
#  'ccristales': 931,
#  'al2mp': 832,
#  'ultra': 2098,
#  'bleulentes': 904,
#  '021000': 26,
#  'ov35gla': 1686,
#  'outdoorlentes': 1681,
#  'sapphireuv': 1919,
#  'dvprogresivosorganico1670sin': 1081,
#  '25292': 303,
#  '0375': 39,
#  'malgla': 1509,
#  '400': 422,
#  '90º': 799,
#  '015402': 21,
#  '65000050lente': 574,
#  'hl': 1276,
#  'ey': 1159,
#  'pol': 1755,
#  'ghrxmonofocalorganico1600hardcon': 1211,
#  'esb': 1121,
#  '288100': 347,
#  'esbgla': 1122,
#  'verdelenteorganica': 2125,
#  'supralentes': 2041,
#  'ov07gla': 1682,
#  'rx4w': 1902,
#  '60050350lentes': 544,
#  '10': 78,
#  'progresiva722802': 1811,
#  'eci': 1084,
#  '478100': 463,
#  'enfoque': 1097,
#  'blanco': 900,
#  'cristalesindf': 983,
#  'indsdegr': 1400,
#  'durcapmonofocalorganico1600con': 1077,
#  'shamirlentes': 1941,
#  'rxlenteorganicaprogresiva': 1907,
#  's17': 1912,
#  'moak': 1562,
#  '9260': 801,
#  'lifest': 1462,
#  'hcristales': 1263,
#  'gf4540': 1206,
#  '676gla': 630,
#  'ex4w2': 1152,
#  '170º': 229,
#  'trsgris': 2087,
#  'ii': 1370,
#  'género': 1248,
#  'espejado': 1136,
#  '001101': 3,
#  'hifin': 1271,
#  'indopack': 1390,
#  'pih': 1731,
#  '13501': 148,
#  '75050125lentes': 716,
#  '590540': 536,
#  'p14lenteorganica': 1696,
#  'psv': 1831,
#  'arlente': 853,
#  '23': 288,
#  'bifical': 890,
#  'hivisioncristales': 1275,
#  'mlenteorganicamonofocal': 1554,
#  '55175675': 515,
#  'lt100005180': 1483,
#  'tr': 2075,
#  'c033': 918,
#  '13881': 154,
#  'ddgla': 1031,
#  'spro': 1985,
#  'trueform': 2089,
#  '518100': 489,
#  'multigressiv': 1592,
#  'xro': 2169,
#  'nk': 1621,
#  '725x': 687,
#  '281gla': 339,
#  'marronmonofocalorganico1502crizal': 1521,
#  'spfin': 1981,
#  'stkmonofocalorganico1500sin': 1994,
#  'st': 1987,
#  'shvlentesmonofocalorgánica': 1954,
#  'marronlentes': 1519,
#  '55325650': 519,
#  'not': 1629,
#  'knowngla': 1418,
#  '75050100lentes': 715,
#  '6cristales': 642,
#  'mezgla': 1543,
#  '14859': 163,
#  'plentes': 1748,
#  'segla': 1927,
#  '202': 271,
#  '17cristales': 241,
#  'suncristales': 2019,
#  '3874': 411,
#  '040': 41,
#  '300': 368,
#  'mms': 1559,
#  'mcristales': 1536,
#  '13435gla': 146,
#  'lens': 1432,
#  'iberia': 1342,
#  'ls3': 1476,
#  'p11': 1687,
#  'elipticocristales': 1092,
#  'imax': 1373,
#  'usr': 2110,
#  'trm': 2086,
#  '2132': 276,
#  'po': 1754,
#  'dv': 1080,
#  'silvercristales': 1965,
#  'ntrlprogresivosorganico1670sin': 1631,
#  'p2mh': 1699,
#  'ptuncfotocromáticocristales': 1847,
#  'metgla': 1541,
#  'tratnatural10': 2084,
#  'pnx': 1753,
#  'rxlentemonofocal': 1904,
#  '217100': 277,
#  '2671': 321,
#  'hd': 1264,
#  '13': 135,
#  'clearlenteorganicaprogresiva': 943,
#  '1127': 106,
#  '75100100lentes': 732,
#  'sapphireuvprogresivo': 1920,
#  'superkid': 2034,
#  's253': 1914,
#  '760': 756,
#  '1500cristales': 170,
#  'pgr': 1720,
#  'hvlllentesorganica': 1324,
#  '0150': 19,
#  '65025275lentes': 589,
#  'czk': 1005,
#  'czkgla': 1006,
#  'epslentes': 1110,
#  '77400': 763,
#  '115º': 114,
#  'hi': 1269,
#  'vision': 2131,
#  'monofocallenteorganicamonofocal': 1572,
#  'm2bk': 1503,
#  '14': 155,
#  '2602': 311,
#  '2877': 345,
#  'rodswsiksgla': 1882,
#  '4830': 468,
#  '6958': 641,
#  '75075150lente': 727,
#  'czd': 1001,
#  'dacristales': 1023,
#  '494': 474,
#  'hil': 1272,
#  ...}

# %%
n = x_train.size
n
# Out:
# 377

# %%
classifier = naive_bayes.MultinomialNB()

model = pipeline.Pipeline([
            ("vectorizer",TfidfVectorizer()),
            ("selector",SelectKBest(chi2, k=50)),
            ("classifier",classifier)])

# %%
# train classifier
model["classifier"].fit(vectorizer, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14404/3887263863.py in <module>
#       1 # train classifier
# ----> 2 model["classifier"].fit(vectorizer, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     610         self : object
#     611         """
# --> 612         X, y = self._check_X_y(X, y)
#     613         _, n_features = X.shape
#     614         self.n_features_ = n_features
#
# ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py in _check_X_y(self, X, y)
#     475
#     476     def _check_X_y(self, X, y):
# --> 477         return self._validate_data(X, y, accept_sparse='csr')
#     478
#     479     def _update_class_log_prior(self, class_prior=None):
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     869         raise ValueError("y cannot be None")
#     870
# --> 871     X = check_array(X, accept_sparse=accept_sparse,
#     872                     accept_large_sparse=accept_large_sparse,
#     873                     dtype=dtype, order=order, copy=copy,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     685             # If input is scalar raise error
#     686             if array.ndim == 0:
# --> 687                 raise ValueError(
#     688                     "Expected 2D array, got scalar array instead:\narray={}.\n"
#     689                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got scalar array instead:
# array=TfidfVectorizer().
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
# test
X_test = data_test["text_combined"].values

# %%
predicted = model.predict(X_test)
predicted_prob = model.predict_proba(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7076/2172222446.py in <module>
# ----> 1 predicted = model.predict(X_test)
#       2 predicted_prob = model.predict_proba(X_test)
#
# ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py in predict(self, X)
#      72         """
#      73         check_is_fitted(self)
# ---> 74         X = self._check_X(X)
#      75         jll = self._joint_log_likelihood(X)
#      76         return self.classes_[np.argmax(jll, axis=1)]
#
# ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py in _check_X(self, X)
#     472
#     473     def _check_X(self, X):
# --> 474         return check_array(X, accept_sparse='csr')
#     475
#     476     def _check_X_y(self, X, y):
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: '804307 VARILUX COMFORT 30 ORMIX 16 CRIZAL SUN UV PHYSIOTINTS GRIS C OJO IZQ ESF 125 CIL 15 EJE 90 ADIC 25 DIAM 6570LENTESORGANICA PROGRESIVA'

# %%
#Evaluate model
classes = np.unique(y_test)
y_test_array = pd.get_dummies(y_test, drop_first=False).values

precision = precision_score(y_test, predicted, average='micro', zero_division=0)
print('Precision score: {0:0.2f}'.format(precision))

recall = recall_score(y_test, predicted, average='micro', zero_division=0)
print('Recall score: {0:0.2f}'.format(recall))

f1 = f1_score(y_test, predicted, average='micro', zero_division=0)
print('f1 score: {0:0.2f}'.format(recall))
# Out:
# Precision score: 0.07
# Recall score: 0.07
# f1 score: 0.07
